# %%
import altair as alt
import numpy as np
import pandas as pd
from pprint import pprint
#write up is in docx file

# %%
from typing import Union
Data = Union[dict, pd.DataFrame]

def data_transformer(data: Data) -> Data:
    # Transform and return the data
    return transformed_data

# %%
import chardet
with open(r'sportsref_download.csv', 'rb') as f:
    result = chardet.detect(f.read())
    draft07 = pd.read_csv(r'sportsref_download.csv', encoding=result['encoding'])
    
df = draft07.head(100)
df
# Out:
#       Rk    Pk   Tm              Player             College   Yrs      G  \
# 0    1.0   1.0  POR           Greg Oden          Ohio State   3.0  105.0
# 1    2.0   2.0  SEA        Kevin Durant               Texas  12.0  849.0
# 2    3.0   3.0  ATL          Al Horford             Florida  13.0  846.0
# 3    4.0   4.0  MEM         Mike Conley          Ohio State  13.0  829.0
# 4    5.0   5.0  BOS          Jeff Green          Georgetown  12.0  900.0
# 5    6.0   6.0  MIL         Yi Jianlian                 NaN   5.0  272.0
# 6    7.0   7.0  MIN        Corey Brewer             Florida  12.0  814.0
# 7    8.0   8.0  CHA      Brandan Wright                 UNC  10.0  428.0
# 8    9.0   9.0  CHI         Joakim Noah             Florida  12.0  667.0
# 9   10.0  10.0  SAC       Spencer Hawes          Washington  10.0  684.0
# 10  11.0  11.0  ATL            Acie Law           Texas A&M   4.0  188.0
# 11  12.0  12.0  PHI      Thaddeus Young        Georgia Tech  13.0  965.0
# 12  13.0  13.0  NOK       Julian Wright              Kansas   4.0  231.0
# 13  14.0  14.0  LAC         Al Thornton       Florida State   4.0  296.0
# 14  15.0  15.0  DET      Rodney Stuckey  Eastern Washington  10.0  651.0
# 15  16.0  16.0  WAS          Nick Young                 USC  12.0  720.0
# 16  17.0  17.0  NJN       Sean Williams      Boston College   4.0  137.0
# 17  18.0  18.0  GSW     Marco Belinelli                 NaN  13.0  855.0
# 18  19.0  19.0  LAL  Javaris Crittenton        Georgia Tech   2.0  113.0
# 19  20.0  20.0  MIA         Jason Smith      Colorado State  11.0  616.0
# 20  21.0  21.0  PHI        Daequan Cook          Ohio State   6.0  328.0
# 21  22.0  22.0  CHA        Jared Dudley      Boston College  13.0  887.0
# 22  23.0  23.0  NYK     Wilson Chandler              DePaul  12.0  676.0
# 23  24.0  24.0  PHO      Rudy Fernández                 NaN   4.0  249.0
# 24  25.0  25.0  UTA       Morris Almond     Rice University   3.0   38.0
# 25  26.0  26.0  HOU        Aaron Brooks              Oregon  10.0  645.0
# 26  27.0  27.0  DET       Arron Afflalo                UCLA  11.0  762.0
# 27  28.0  28.0  SAS      Tiago Splitter                 NaN   7.0  355.0
# 28  29.0  29.0  PHO       Alando Tucker           Wisconsin   3.0   51.0
# 29  30.0  30.0  PHI     Petteri Koponen                 NaN   NaN    NaN
# ..   ...   ...  ...                 ...                 ...   ...    ...
# 31  32.0  32.0  BOS         Gabe Pruitt                 USC   2.0   62.0
# 32  33.0  33.0  SAS     Marcus Williams             Arizona   2.0   13.0
# 33  34.0  34.0  DAL        Nick Fazekas              Nevada   1.0   26.0
# 34  35.0  35.0  SEA          Glen Davis                 LSU   8.0  514.0
# 35  36.0  36.0  GSW   Jermareo Davidson             Alabama   2.0   52.0
# 36  37.0  37.0  POR      Josh McRoberts                Duke  11.0  433.0
# 37  38.0  38.0  PHI      Kyrylo Fesenko                 NaN   5.0  135.0
# 38  39.0  39.0  MIA        Stanko Barać                 NaN   NaN    NaN
# 39  40.0  40.0  LAL             Sun Yue                 NaN   1.0   10.0
# 40  41.0  41.0  MIN       Chris Richard             Florida   2.0   70.0
# 41  42.0  42.0  POR       Derrick Byars          Vanderbilt   1.0    2.0
# 42  43.0  43.0  NOK        Adam Haluska                Iowa   NaN    NaN
# 43  44.0  44.0  ORL      Reyshawn Terry                 UNC   NaN    NaN
# 44  45.0  45.0  LAC        Jared Jordan      Marist College   NaN    NaN
# 45  46.0  46.0  GSW      Stéphane Lasme               UMass   1.0   16.0
# 46  47.0  47.0  WAS     Dominic McGuire        Fresno State   6.0  342.0
# 47  48.0  48.0  LAL          Marc Gasol                 NaN  12.0  831.0
# 48  49.0  49.0  CHI          Aaron Gray                Pitt   7.0  318.0
# 49  50.0  50.0  DAL   Renaldas Seibutis                 NaN   NaN    NaN
# 50  51.0  51.0  CHI       JamesOn Curry      Oklahoma State   1.0    1.0
# 51  52.0  52.0  POR       Taurean Green             Florida   1.0   17.0
# 52  53.0  53.0  POR    Demetris Nichols            Syracuse   2.0   18.0
# 53  54.0  54.0  HOU         Brad Newley                 NaN   NaN    NaN
# 54  55.0  55.0  UTA        Herbert Hill          Providence   NaN    NaN
# 55  56.0  56.0  MIL      Ramon Sessions              Nevada  11.0  691.0
# 56  57.0  57.0  DET         Sammy Mejia              DePaul   NaN    NaN
# 57  58.0  58.0  SAS  Georgios Printezis                 NaN   NaN    NaN
# 58  59.0  59.0  PHO     D.J. Strawberry            Maryland   1.0   33.0
# 59  60.0  60.0  DAL     Milovan Raković                 NaN   NaN    NaN
# 60   NaN   NaN  NaN                 NaN                 NaN   NaN    NaN
#
#          MP      PTS     TRB  ...    3P%    FT%  MP.1  PTS.1  TRB.1  AST.1  \
# 0    2028.0    840.0   656.0  ...    NaN  0.658  19.3    8.0    6.2    0.5
# 1   31305.0  22940.0  5992.0  ...  0.381  0.883  36.9   27.0    7.1    4.1
# 2   27633.0  11814.0  7009.0  ...  0.361  0.754  32.7   14.0    8.3    3.3
# 3   26871.0  12300.0  2460.0  ...  0.375  0.818  32.4   14.8    3.0    5.7
# 4   26573.0  11657.0  3988.0  ...  0.334  0.805  29.5   13.0    4.4    1.6
# 5    6038.0   2148.0  1339.0  ...  0.333  0.780  22.2    7.9    4.9    0.7
# 6   18738.0   7092.0  2279.0  ...  0.284  0.713  23.0    8.7    2.8    1.5
# 7    6949.0   2976.0  1560.0  ...  0.000  0.674  16.2    7.0    3.6    0.5
# 8   18596.0   5867.0  6042.0  ...  0.000  0.700  27.9    8.8    9.1    2.8
# 9   15541.0   5932.0  3893.0  ...  0.350  0.716  22.7    8.7    5.7    1.9
# 10   2385.0    725.0   195.0  ...  0.235  0.778  12.7    3.9    1.0    1.6
NaN      NaN     NaN  ...    NaN    NaN   NaN    NaN    NaN    NaN
# 50      0.0      0.0     0.0  ...    NaN    NaN   0.0    0.0    0.0    0.0
# 51     74.0     27.0    10.0  ...  0.182  0.917   4.4    1.6    0.6    0.6
# 52     58.0     22.0     7.0  ...  0.200  0.500   3.2    1.2    0.4    0.1
# 53      NaN      NaN     NaN  ...    NaN    NaN   NaN    NaN    NaN    NaN
# 54      NaN      NaN     NaN  ...    NaN    NaN   NaN    NaN    NaN    NaN
# 55  16119.0   7141.0  1840.0  ...  0.316  0.791  23.3   10.3    2.7    4.1
# 56      NaN      NaN     NaN  ...    NaN    NaN   NaN    NaN    NaN    NaN
# 57      NaN      NaN     NaN  ...    NaN    NaN   NaN    NaN    NaN    NaN
# 58    270.0     73.0    28.0  ...  0.240  0.474   8.2    2.2    0.8    0.9
# 59      NaN      NaN     NaN  ...    NaN    NaN   NaN    NaN    NaN    NaN
# 60      NaN      NaN     NaN  ...    NaN    NaN   NaN    NaN    NaN    NaN
#
#        WS  WS/48   BPM  VORP
# 0     7.3  0.174  -0.4   0.8
# 1   141.7  0.217   6.7  69.0
# 2    90.7  0.158   2.8  33.4
# 3    73.5  0.131   2.3  29.3
# 4    41.6  0.075  -1.3   4.3
# 5     3.1  0.025  -4.3  -3.5
# 6    22.5  0.058  -1.6   2.0
# 7    26.2  0.181   2.3   7.5
# 8    61.8  0.160   2.5  20.9
# 9    22.6  0.070  -1.1   3.4
# 10    1.6  0.032  -3.9  -1.1
# 11   61.6  0.101   0.3  16.9
# 12    3.9  0.061  -0.5   1.2
# 13    6.1  0.035  -3.5  -3.2
# 14   28.7  0.077  -0.9   4.9
# 15   18.6  0.054  -2.2  -0.8
# 16    3.0  0.073  -3.1  -0.6
# 17   30.2  0.075  -1.3   3.3
# 18    0.1  0.002  -4.2  -1.0
# 19   14.1  0.067  -2.9  -2.4
# 20    4.9  0.039  -2.7  -1.1
# 21   42.8  0.103   0.2  11.1
# 22   29.0  0.069  -1.3   3.5
# 23   14.2  0.114   1.7   5.6
# 24    0.0  0.005  -6.1  -0.4
# 25   19.2  0.069  -1.2   2.7
# 26   33.5  0.077  -1.5   2.4
# 27   25.3  0.178   1.1   5.4
# 28    0.4  0.045  -4.5  -0.3
# 29    NaN    NaN   NaN   NaN
# ..    ...    ...   ...   ...
# 31    0.4  0.043  -2.8  -0.1
# 32   -0.1 -0.084  -5.4   0.0
# 33    0.8  0.148   0.5   0.2
# 34   18.6  0.082  -2.6  -1.7
# 35    0.0  0.000  -5.2  -0.3
# 36   18.5  0.107   0.3   4.7
# 37    0.9  0.038  -5.7  -1.1
# 38    NaN    NaN   NaN   NaN
# 39   -0.1 -0.226 -19.4  -0.1
# 40    0.7  0.045  -5.7  -0.7
# 41    0.1  0.147  -4.7   0.0
# 42    NaN    NaN   NaN   NaN
# 43    NaN    NaN   NaN   NaN
# 44    NaN    NaN   NaN   NaN
# 45    0.3  0.041  -4.4  -0.2
# 46    4.1  0.037  -2.1  -0.1
# 47   82.2  0.143   3.1  35.4
# 48    6.2  0.077  -3.6  -1.5
# 49    NaN    NaN   NaN   NaN
# 50    0.0    NaN   NaN   0.0
# 51   -0.1 -0.066  -7.5  -0.1
# 52   -0.2 -0.203 -10.3  -0.1
# 53    NaN    NaN   NaN   NaN
# 54    NaN    NaN   NaN   NaN
# 55   28.8  0.086  -0.7   5.2
# 56    NaN    NaN   NaN   NaN
# 57    NaN    NaN   NaN   NaN
# 58   -0.2 -0.031  -5.6  -0.2
# 59    NaN    NaN   NaN   NaN
# 60    NaN    NaN   NaN   NaN
#
# [61 rows x 22 columns]

# %%
df = df.dropna()

# %%
df
# Out:
#       Rk    Pk   Tm              Player             College   Yrs      G  \
# 1    2.0   2.0  SEA        Kevin Durant               Texas  12.0  849.0
# 2    3.0   3.0  ATL          Al Horford             Florida  13.0  846.0
# 3    4.0   4.0  MEM         Mike Conley          Ohio State  13.0  829.0
# 4    5.0   5.0  BOS          Jeff Green          Georgetown  12.0  900.0
# 6    7.0   7.0  MIN        Corey Brewer             Florida  12.0  814.0
# 7    8.0   8.0  CHA      Brandan Wright                 UNC  10.0  428.0
# 8    9.0   9.0  CHI         Joakim Noah             Florida  12.0  667.0
# 9   10.0  10.0  SAC       Spencer Hawes          Washington  10.0  684.0
# 10  11.0  11.0  ATL            Acie Law           Texas A&M   4.0  188.0
# 11  12.0  12.0  PHI      Thaddeus Young        Georgia Tech  13.0  965.0
# 12  13.0  13.0  NOK       Julian Wright              Kansas   4.0  231.0
# 13  14.0  14.0  LAC         Al Thornton       Florida State   4.0  296.0
# 14  15.0  15.0  DET      Rodney Stuckey  Eastern Washington  10.0  651.0
# 15  16.0  16.0  WAS          Nick Young                 USC  12.0  720.0
# 16  17.0  17.0  NJN       Sean Williams      Boston College   4.0  137.0
# 18  19.0  19.0  LAL  Javaris Crittenton        Georgia Tech   2.0  113.0
# 19  20.0  20.0  MIA         Jason Smith      Colorado State  11.0  616.0
# 20  21.0  21.0  PHI        Daequan Cook          Ohio State   6.0  328.0
# 21  22.0  22.0  CHA        Jared Dudley      Boston College  13.0  887.0
# 22  23.0  23.0  NYK     Wilson Chandler              DePaul  12.0  676.0
# 24  25.0  25.0  UTA       Morris Almond     Rice University   3.0   38.0
# 25  26.0  26.0  HOU        Aaron Brooks              Oregon  10.0  645.0
# 26  27.0  27.0  DET       Arron Afflalo                UCLA  11.0  762.0
# 28  29.0  29.0  PHO       Alando Tucker           Wisconsin   3.0   51.0
# 30  31.0  31.0  SEA         Carl Landry              Purdue   9.0  513.0
# 31  32.0  32.0  BOS         Gabe Pruitt                 USC   2.0   62.0
# 33  34.0  34.0  DAL        Nick Fazekas              Nevada   1.0   26.0
# 34  35.0  35.0  SEA          Glen Davis                 LSU   8.0  514.0
# 36  37.0  37.0  POR      Josh McRoberts                Duke  11.0  433.0
# 41  42.0  42.0  POR       Derrick Byars          Vanderbilt   1.0    2.0
# 46  47.0  47.0  WAS     Dominic McGuire        Fresno State   6.0  342.0
# 48  49.0  49.0  CHI          Aaron Gray                Pitt   7.0  318.0
# 51  52.0  52.0  POR       Taurean Green             Florida   1.0   17.0
# 52  53.0  53.0  POR    Demetris Nichols            Syracuse   2.0   18.0
# 55  56.0  56.0  MIL      Ramon Sessions              Nevada  11.0  691.0
# 58  59.0  59.0  PHO     D.J. Strawberry            Maryland   1.0   33.0
#
#          MP      PTS     TRB  ...    3P%    FT%  MP.1  PTS.1  TRB.1  AST.1  \
# 1   31305.0  22940.0  5992.0  ...  0.381  0.883  36.9   27.0    7.1    4.1
# 2   27633.0  11814.0  7009.0  ...  0.361  0.754  32.7   14.0    8.3    3.3
# 1   141.7  0.217   6.7  69.0
# 2    90.7  0.158   2.8  33.4
# 3    73.5  0.131   2.3  29.3
# 4    41.6  0.075  -1.3   4.3
# 6    22.5  0.058  -1.6   2.0
# 7    26.2  0.181   2.3   7.5
# 8    61.8  0.160   2.5  20.9
# 9    22.6  0.070  -1.1   3.4
# 10    1.6  0.032  -3.9  -1.1
# 11   61.6  0.101   0.3  16.9
# 12    3.9  0.061  -0.5   1.2
# 13    6.1  0.035  -3.5  -3.2
# 14   28.7  0.077  -0.9   4.9
# 15   18.6  0.054  -2.2  -0.8
# 16    3.0  0.073  -3.1  -0.6
# 18    0.1  0.002  -4.2  -1.0
# 19   14.1  0.067  -2.9  -2.4
# 20    4.9  0.039  -2.7  -1.1
# 21   42.8  0.103   0.2  11.1
# 22   29.0  0.069  -1.3   3.5
# 24    0.0  0.005  -6.1  -0.4
# 25   19.2  0.069  -1.2   2.7
# 26   33.5  0.077  -1.5   2.4
# 28    0.4  0.045  -4.5  -0.3
# 30   35.9  0.149  -0.3   5.0
# 31    0.4  0.043  -2.8  -0.1
# 33    0.8  0.148   0.5   0.2
# 34   18.6  0.082  -2.6  -1.7
# 36   18.5  0.107   0.3   4.7
# 41    0.1  0.147  -4.7   0.0
# 46    4.1  0.037  -2.1  -0.1
# 48    6.2  0.077  -3.6  -1.5
# 51   -0.1 -0.066  -7.5  -0.1
# 52   -0.2 -0.203 -10.3  -0.1
# 55   28.8  0.086  -0.7   5.2
# 58   -0.2 -0.031  -5.6  -0.2
#
# [36 rows x 22 columns]

# %%
alt.Chart(draft07).mark_point().encode(
    alt.X('PTS'),
    alt.Y('G'),
    alt.Size('Pk'),
    tooltip = [alt.Tooltip('Player'),
               alt.Tooltip('PTS'),
               alt.Tooltip('G'),
               alt.Tooltip('Pk')
              ]
).interactive()
# Out:
# alt.Chart(...)

# %%
alt.Chart(draft07).mark_point().encode(
    x = "G",
    y = "PTS",
    color = "Tm",
    size = "Pk",
    tooltip=["Player", "Rk"]
).interactive()
# Out:
# alt.Chart(...)

# %%
gasolplusOden = pd.read_csv("gasolpulsOden.csv")
gasolplusOden.head
# Out:
# <bound method NDFrame.head of    Rk  Pk   Tm      Player     College  Yrs    G     MP    PTS   TRB  ...  \
# 0   1   1  POR   Greg Oden  Ohio State    3  105   2028    840   656  ...
# 1  48  48  LAL  Marc Gasol         NaN   12  831  27555  12196  6342  ...
#
#      3P%    FT%  MP.1  PTS.1  TRB.1  AST.1    WS  WS/48  BPM  VORP
# 0    NaN  0.658  19.3    8.0    6.2    0.5   7.3  0.174 -0.4   0.8
# 1  0.356  0.777  33.2   14.7    7.6    3.4  82.2  0.143  3.1  35.4
#
# [2 rows x 22 columns]>

# %%
likely_counts = gasolplusOden['PTS']
print("Greg Oden's Carrer Point vs Kyle Korver")
print("Player - Carrer Points")
print(likely_counts)
likely_counts.plot(kind='bar', figsize=(7,5), color="green")
print("0 - Greg Oden, 1 - Kyle Korver")
# Out:
# Greg Oden's Carrer Point vs Kyle Korver
# Player - Carrer Points
# 0      840
# 1    12196
# Name: PTS, dtype: int64
# 0 - Greg Oden, 1 - Kyle Korver

# %%
import altair as alt
from vega_datasets import data

source = data.draft07()

alt.Chart(source).mark_bar().encode(
    x='Player',
    y='G',
    color='site'
)

# %%
alt.Chart(draft07).mark_point().encode(
    x = "G",
    y = "PTS",
    tooltip=["Player", "Rk"]
).interactive()
# Out:
# alt.Chart(...)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from scipy.optimize import curve_fit
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.cluster import KMeans
from sklearn.feature_selection import mutual_info_classif

# %%
def runKNN(df, x, y, k): 
    # Let's assume that we're using numeric features to predict a categorical label
    X = x.values
    Y = y.values.reshape(-1, 1)
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=1, stratify=Y)
    
    # Build a kNN classifier
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, Y_train)
    
    # Compute the quality of our predictions
    score = knn.score(X_test, Y_test)
    print("Predicts " + y.name + " with " + str(score) + " accuracy")
    print("F1 score is " + str(f1_score(Y_test, knn.predict(X_test), labels=y.unique(), average='weighted')))
    print("Chance is: " + str(1.0 / len(y.unique())))
    
    return knn

# %%
def loadAndCleanData(df):
    data = pd.read_csv(df)
    data = data.fillna(0)
    #print(data)
    return data

# %%
df
# Out:
#       Rk    Pk   Tm              Player             College   Yrs      G  \
# 1    2.0   2.0  SEA        Kevin Durant               Texas  12.0  849.0
# 2    3.0   3.0  ATL          Al Horford             Florida  13.0  846.0
# 3    4.0   4.0  MEM         Mike Conley          Ohio State  13.0  829.0
# 4    5.0   5.0  BOS          Jeff Green          Georgetown  12.0  900.0
# 6    7.0   7.0  MIN        Corey Brewer             Florida  12.0  814.0
# 7    8.0   8.0  CHA      Brandan Wright                 UNC  10.0  428.0
# 8    9.0   9.0  CHI         Joakim Noah             Florida  12.0  667.0
# 9   10.0  10.0  SAC       Spencer Hawes          Washington  10.0  684.0
# 10  11.0  11.0  ATL            Acie Law           Texas A&M   4.0  188.0
# 11  12.0  12.0  PHI      Thaddeus Young        Georgia Tech  13.0  965.0
# 12  13.0  13.0  NOK       Julian Wright              Kansas   4.0  231.0
# 13  14.0  14.0  LAC         Al Thornton       Florida State   4.0  296.0
# 14  15.0  15.0  DET      Rodney Stuckey  Eastern Washington  10.0  651.0
# 15  16.0  16.0  WAS          Nick Young                 USC  12.0  720.0
# 16  17.0  17.0  NJN       Sean Williams      Boston College   4.0  137.0
# 18  19.0  19.0  LAL  Javaris Crittenton        Georgia Tech   2.0  113.0
# 19  20.0  20.0  MIA         Jason Smith      Colorado State  11.0  616.0
# 20  21.0  21.0  PHI        Daequan Cook          Ohio State   6.0  328.0
# 21  22.0  22.0  CHA        Jared Dudley      Boston College  13.0  887.0
# 22  23.0  23.0  NYK     Wilson Chandler              DePaul  12.0  676.0
# 24  25.0  25.0  UTA       Morris Almond     Rice University   3.0   38.0
# 25  26.0  26.0  HOU        Aaron Brooks              Oregon  10.0  645.0
# 26  27.0  27.0  DET       Arron Afflalo                UCLA  11.0  762.0
# 28  29.0  29.0  PHO       Alando Tucker           Wisconsin   3.0   51.0
# 30  31.0  31.0  SEA         Carl Landry              Purdue   9.0  513.0
# 31  32.0  32.0  BOS         Gabe Pruitt                 USC   2.0   62.0
# 30  11524.0   5541.0  2533.0  ...  0.300  0.785  22.5   10.8    4.9    0.7
# 31    461.0    125.0    51.0  ...  0.283  0.783   7.4    2.0    0.8    0.8
# 33    269.0    107.0    89.0  ...  0.000  0.682  10.3    4.1    3.4    0.4
# 34  10865.0   4111.0  2236.0  ...  0.182  0.700  21.1    8.0    4.4    0.9
# 36   8271.0   2333.0  1686.0  ...  0.340  0.705  19.1    5.4    3.9    2.1
# 41     37.0     10.0    11.0  ...  0.000  1.000  18.5    5.0    5.5    0.5
# 46   5348.0    939.0  1169.0  ...  0.188  0.658  15.6    2.7    3.4    1.2
# 48   3851.0   1066.0  1190.0  ...  0.000  0.562  12.1    3.4    3.7    0.7
# 51     74.0     27.0    10.0  ...  0.182  0.917   4.4    1.6    0.6    0.6
# 52     58.0     22.0     7.0  ...  0.200  0.500   3.2    1.2    0.4    0.1
# 55  16119.0   7141.0  1840.0  ...  0.316  0.791  23.3   10.3    2.7    4.1
# 58    270.0     73.0    28.0  ...  0.240  0.474   8.2    2.2    0.8    0.9
#
#        WS  WS/48   BPM  VORP
# 1   141.7  0.217   6.7  69.0
# 2    90.7  0.158   2.8  33.4
# 3    73.5  0.131   2.3  29.3
# 4    41.6  0.075  -1.3   4.3
# 6    22.5  0.058  -1.6   2.0
# 7    26.2  0.181   2.3   7.5
# 8    61.8  0.160   2.5  20.9
# 9    22.6  0.070  -1.1   3.4
# 10    1.6  0.032  -3.9  -1.1
# 11   61.6  0.101   0.3  16.9
# 12    3.9  0.061  -0.5   1.2
# 13    6.1  0.035  -3.5  -3.2
# 14   28.7  0.077  -0.9   4.9
# 15   18.6  0.054  -2.2  -0.8
# 16    3.0  0.073  -3.1  -0.6
# 18    0.1  0.002  -4.2  -1.0
# 19   14.1  0.067  -2.9  -2.4
# 20    4.9  0.039  -2.7  -1.1
# 21   42.8  0.103   0.2  11.1
# 22   29.0  0.069  -1.3   3.5
# 24    0.0  0.005  -6.1  -0.4
# 25   19.2  0.069  -1.2   2.7
# 26   33.5  0.077  -1.5   2.4
# 28    0.4  0.045  -4.5  -0.3
# 30   35.9  0.149  -0.3   5.0
# 31    0.4  0.043  -2.8  -0.1
# 33    0.8  0.148   0.5   0.2
# 34   18.6  0.082  -2.6  -1.7
# 36   18.5  0.107   0.3   4.7
# 41    0.1  0.147  -4.7   0.0
# 46    4.1  0.037  -2.1  -0.1
# 48    6.2  0.077  -3.6  -1.5
# 51   -0.1 -0.066  -7.5  -0.1
# 52   -0.2 -0.203 -10.3  -0.1
# 55   28.8  0.086  -0.7   5.2
# 58   -0.2 -0.031  -5.6  -0.2
#
# [36 rows x 22 columns]

# %%
# Predict position as a function of goals (mirroring regression)
# Note that x should be a dataframe (hence the double [])
x = df[["G"]]
y = df["Yrs"]

# Run kNN with one neighbor
runKNN(df, x, y, 1)

# Run kNN with five neighbors
runKNN(df, x, y, 5)

# Measure performance for different values for k
for k in range(1, 10): 
    print(str(k) + " neighbors:")
    runKNN(df, x, y, k)
    
# Print out the number of datapoints in each class
y.value_counts()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-e5515b19a752> in <module>
#       5
#       6 # Run kNN with one neighbor
# ----> 7 runKNN(df, x, y, 1)
#       8
#       9 # Run kNN with five neighbors
#
# <ipython-input-35-4c7eebb86b19> in runKNN(df, x, y, k)
#       3     X = x.values
#       4     Y = y.values.reshape(-1, 1)
# ----> 5     X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=1, stratify=Y)
#       6
#       7     # Build a kNN classifier
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py in train_test_split(*arrays, **options)
#    2119                      random_state=random_state)
#    2120
# -> 2121         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2122
#    2123     return list(chain.from_iterable((safe_indexing(a, train),
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#    1321         """
#    1322         X, y, groups = indexable(X, y, groups)
# -> 1323         for train, test in self._iter_indices(X, y, groups):
#    1324             yield train, test
#    1325
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py in _iter_indices(self, X, y, groups)
#    1634         class_counts = np.bincount(y_indices)
#    1635         if np.min(class_counts) < 2:
# -> 1636             raise ValueError("The least populated class in y has only 1"
#    1637                              " member, which is too few. The minimum"
#    1638                              " number of groups for any class cannot"
#
# ValueError: The least populated class in y has only 1 member, which is too few. The minimum number of groups for any class cannot be less than 2.

# %%
# Now let's run with a broader set of data
# We can use ALL of our numeric data to make a prediction
x = df.select_dtypes(include="number")
y = df["G"]

# Run k-NN for two different values of k
runKNN(df, x, y, 1)
runKNN(df, x, y, 5)

# Find the best k to predict position. 
# We can do this by looking at the accuracy for each setting of k
# and choosing the k that gives us the best performance
for k in range(1, 10): 
    print(str(k) + " Neighbors:")
    runKNN(df, x, y, k)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-64f5b8be82cb> in <module>
#       5
#       6 # Run k-NN for two different values of k
# ----> 7 runKNN(df, x, y, 1)
#       8 runKNN(df, x, y, 5)
#       9
#
# <ipython-input-35-4c7eebb86b19> in runKNN(df, x, y, k)
#       3     X = x.values
#       4     Y = y.values.reshape(-1, 1)
# ----> 5     X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=1, stratify=Y)
#       6
#       7     # Build a kNN classifier
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py in train_test_split(*arrays, **options)
#    2119                      random_state=random_state)
#    2120
# -> 2121         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2122
#    2123     return list(chain.from_iterable((safe_indexing(a, train),
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#    1321         """
#    1322         X, y, groups = indexable(X, y, groups)
# -> 1323         for train, test in self._iter_indices(X, y, groups):
#    1324             yield train, test
#    1325
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py in _iter_indices(self, X, y, groups)
#    1634         class_counts = np.bincount(y_indices)
#    1635         if np.min(class_counts) < 2:
# -> 1636             raise ValueError("The least populated class in y has only 1"
#    1637                              " member, which is too few. The minimum"
#    1638                              " number of groups for any class cannot"
#
# ValueError: The least populated class in y has only 1 member, which is too few. The minimum number of groups for any class cannot be less than 2.

# %%
df
# Out:
#       Rk    Pk   Tm              Player             College   Yrs      G  \
# 1    2.0   2.0  SEA        Kevin Durant               Texas  12.0  849.0
# 2    3.0   3.0  ATL          Al Horford             Florida  13.0  846.0
# 3    4.0   4.0  MEM         Mike Conley          Ohio State  13.0  829.0
# 4    5.0   5.0  BOS          Jeff Green          Georgetown  12.0  900.0
# 6    7.0   7.0  MIN        Corey Brewer             Florida  12.0  814.0
# 7    8.0   8.0  CHA      Brandan Wright                 UNC  10.0  428.0
# 8    9.0   9.0  CHI         Joakim Noah             Florida  12.0  667.0
# 9   10.0  10.0  SAC       Spencer Hawes          Washington  10.0  684.0
# 10  11.0  11.0  ATL            Acie Law           Texas A&M   4.0  188.0
# 11  12.0  12.0  PHI      Thaddeus Young        Georgia Tech  13.0  965.0
# 12  13.0  13.0  NOK       Julian Wright              Kansas   4.0  231.0
# 13  14.0  14.0  LAC         Al Thornton       Florida State   4.0  296.0
# 14  15.0  15.0  DET      Rodney Stuckey  Eastern Washington  10.0  651.0
# 15  16.0  16.0  WAS          Nick Young                 USC  12.0  720.0
# 16  17.0  17.0  NJN       Sean Williams      Boston College   4.0  137.0
# 18  19.0  19.0  LAL  Javaris Crittenton        Georgia Tech   2.0  113.0
# 19  20.0  20.0  MIA         Jason Smith      Colorado State  11.0  616.0
# 20  21.0  21.0  PHI        Daequan Cook          Ohio State   6.0  328.0
# 21  22.0  22.0  CHA        Jared Dudley      Boston College  13.0  887.0
# 22  23.0  23.0  NYK     Wilson Chandler              DePaul  12.0  676.0
# 24  25.0  25.0  UTA       Morris Almond     Rice University   3.0   38.0
# 25  26.0  26.0  HOU        Aaron Brooks              Oregon  10.0  645.0
# 26  27.0  27.0  DET       Arron Afflalo                UCLA  11.0  762.0
# 28  29.0  29.0  PHO       Alando Tucker           Wisconsin   3.0   51.0
# 30  31.0  31.0  SEA         Carl Landry              Purdue   9.0  513.0
# 31  32.0  32.0  BOS         Gabe Pruitt                 USC   2.0   62.0
# 33  34.0  34.0  DAL        Nick Fazekas              Nevada   1.0   26.0
# 34  35.0  35.0  SEA          Glen Davis                 LSU   8.0  514.0
# 36  37.0  37.0  POR      Josh McRoberts                Duke  11.0  433.0
# 41  42.0  42.0  POR       Derrick Byars          Vanderbilt   1.0    2.0
# 46  47.0  47.0  WAS     Dominic McGuire        Fresno State   6.0  342.0
# 48  49.0  49.0  CHI          Aaron Gray                Pitt   7.0  318.0
# 51  52.0  52.0  POR       Taurean Green             Florida   1.0   17.0
# 52  53.0  53.0  POR    Demetris Nichols            Syracuse   2.0   18.0
# 55  56.0  56.0  MIL      Ramon Sessions              Nevada  11.0  691.0
# 58  59.0  59.0  PHO     D.J. Strawberry            Maryland   1.0   33.0
#
#          MP      PTS     TRB  ...    3P%    FT%  MP.1  PTS.1  TRB.1  AST.1  \
# 1   31305.0  22940.0  5992.0  ...  0.381  0.883  36.9   27.0    7.1    4.1
# 2   27633.0  11814.0  7009.0  ...  0.361  0.754  32.7   14.0    8.3    3.3
# 3   26871.0  12300.0  2460.0  ...  0.375  0.818  32.4   14.8    3.0    5.7
# 4   26573.0  11657.0  3988.0  ...  0.334  0.805  29.5   13.0    4.4    1.6
# 6   18738.0   7092.0  2279.0  ...  0.284  0.713  23.0    8.7    2.8    1.5
# 7    6949.0   2976.0  1560.0  ...  0.000  0.674  16.2    7.0    3.6    0.5
# 8   18596.0   5867.0  6042.0  ...  0.000  0.700  27.9    8.8    9.1    2.8
# 9   15541.0   5932.0  3893.0  ...  0.350  0.716  22.7    8.7    5.7    1.9
# 10   2385.0    725.0   195.0  ...  0.235  0.778  12.7    3.9    1.0    1.6
# 11  29281.0  12703.0  5714.0  ...  0.333  0.670  30.3   13.2    5.9    1.7
# 12   3049.0    907.0   531.0  ...  0.262  0.584  13.2    3.9    2.3    0.8
# 13   8274.0   3527.0  1233.0  ...  0.293  0.747  28.0   11.9    4.2    1.2
# 14  17890.0   8185.0  1912.0  ...  0.300  0.824  27.5   12.6    2.9    3.6
# 15  16419.0   8194.0  1427.0  ...  0.376  0.836  22.8   11.4    2.0    1.0
# 31    0.4  0.043  -2.8  -0.1
# 33    0.8  0.148   0.5   0.2
# 34   18.6  0.082  -2.6  -1.7
# 36   18.5  0.107   0.3   4.7
# 41    0.1  0.147  -4.7   0.0
# 46    4.1  0.037  -2.1  -0.1
# 48    6.2  0.077  -3.6  -1.5
# 51   -0.1 -0.066  -7.5  -0.1
# 52   -0.2 -0.203 -10.3  -0.1
# 55   28.8  0.086  -0.7   5.2
# 58   -0.2 -0.031  -5.6  -0.2
#
# [36 rows x 22 columns]

# %%
player = df[df["Player"] == "Marc Gasol"]
print(player)
playerData = player.select_dtypes(include="number")

# Build a model to use in prediction. We can see that our classifier doesn't get Ovechkin's position
# right, but is close (a LW and RW play the same general position, just on different halves of the ice)
model = runKNN(df, x, y, 7)
print("k-NN thinks " + player["Player"] + " is a " + model.predict(playerData)[0])

# We can print out the n players closest to our target (control n by changing n_neighbors). 
# Note that the players are listed in order from closest to farthest
relatedPlayers = model.kneighbors(playerData, n_neighbors=3, return_distance=False)

for p in relatedPlayers[0]: 
    print(df.iloc[int(p)]["Player"])
    
# If we repeat with Mats Zuccarello (player = df[df["Player"] =="Mats Zuccarello\zuccama01"])
# we see that just because Zuccarello looks most like Ovechkin doesn't mean Ovechkin looks 
# most like Zuccarello (though you'll notice the classifier gets Zuccarello's position right)
# Out:
# Empty DataFrame
# Columns: [Rk, Pk, Tm, Player, College, Yrs, G, MP, PTS, TRB, AST, FG%, 3P%, FT%, MP.1, PTS.1, TRB.1, AST.1, WS, WS/48, BPM, VORP]
# Index: []
#
# [0 rows x 22 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-7650699ac672> in <module>
#       5 # Build a model to use in prediction. We can see that our classifier doesn't get Ovechkin's position
#       6 # right, but is close (a LW and RW play the same general position, just on different halves of the ice)
# ----> 7 model = runKNN(df, x, y, 7)
#       8 print("k-NN thinks " + player["Player"] + " is a " + model.predict(playerData)[0])
#       9
#
# <ipython-input-35-4c7eebb86b19> in runKNN(df, x, y, k)
#       3     X = x.values
#       4     Y = y.values.reshape(-1, 1)
# ----> 5     X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=1, stratify=Y)
#       6
#       7     # Build a kNN classifier
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py in train_test_split(*arrays, **options)
#    2119                      random_state=random_state)
#    2120
# -> 2121         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2122
#    2123     return list(chain.from_iterable((safe_indexing(a, train),
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#    1321         """
#    1322         X, y, groups = indexable(X, y, groups)
# -> 1323         for train, test in self._iter_indices(X, y, groups):
#    1324             yield train, test
#    1325
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py in _iter_indices(self, X, y, groups)
#    1634         class_counts = np.bincount(y_indices)
#    1635         if np.min(class_counts) < 2:
# -> 1636             raise ValueError("The least populated class in y has only 1"
#    1637                              " member, which is too few. The minimum"
#    1638                              " number of groups for any class cannot"
#
# ValueError: The least populated class in y has only 1 member, which is too few. The minimum number of groups for any class cannot be less than 2.

# %%
player = df[df["Player"] == "Greg Oden"]
relatedPlayers = model.kneighbors(player.select_dtypes(include="number"), n_neighbors=5, return_distance=False)

for p in relatedPlayers[0]: 
    print(df.iloc[int(p)]["Player"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-7340b03b7f5d> in <module>
#       1 player = df[df["Player"] == "Greg Oden"]
# ----> 2 relatedPlayers = model.kneighbors(player.select_dtypes(include="number"), n_neighbors=5, return_distance=False)
#       3
#       4 for p in relatedPlayers[0]:
#       5     print(df.iloc[int(p)]["Player"])
#
# NameError: name 'model' is not defined
